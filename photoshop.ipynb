# %% [markdown]
# Import Pillow library and numpy

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# Uploade image and preview

# %%
image = Image.open('apostles.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x377 at 0x1AB1CF72BE0>

# %% [markdown]
# Store the image as an array

# %%
img_data = np.array(image)
img_data.shape
# Out:
# (377, 640, 3)

# %% [markdown]
# Red Only

# %%
img_chn_red = np.zeros(img_data.shape, dtype='uint8')
img_chn_red[:,:,0] = img_data[:,:,0]
image_red = Image.fromarray(img_chn_red)
image_red
# Out:
# <PIL.Image.Image image mode=RGB size=640x377 at 0x1AB2C59A580>

# %% [markdown]
# Green Only

# %%
img_chn_green = np.zeros(img_data.shape, dtype='uint8')
img_chn_green[:,:,1] = img_data[:,:,1]
image_green = Image.fromarray(img_chn_green)
image_green
# Out:
# <PIL.Image.Image image mode=RGB size=640x377 at 0x1AB2C5AF160>

# %% [markdown]
# Blue Only

# %%
img_chn_blue = np.zeros(img_data.shape, dtype='uint8')
img_chn_blue[:,:,2] = img_data[:,:,2]
image_blue = Image.fromarray(img_chn_blue)
image_blue
# Out:
# <PIL.Image.Image image mode=RGB size=640x377 at 0x1AB1CF72AF0>

# %% [markdown]
# Crop the Photo

# %%
img_cropped_data = img_data[60:250, 200:500, :]
img_cropped = Image.fromarray(img_cropped_data)
img_cropped
# Out:
# <PIL.Image.Image image mode=RGB size=300x190 at 0x1AB1CF72B80>

# %% [markdown]
# Flip the Photo

# %%
#TODO - program this myself
img_flipped_data = np.flip(img_data, axis=1)
img_flipped = Image.fromarray(img_flipped_data)
img_flipped
# Out:
# <PIL.Image.Image image mode=RGB size=640x377 at 0x1AB1CF72F70>

# %% [markdown]
# Reverse the Color

# %%
img_reversed_data = 255 - img_data
img_reversed = Image.fromarray(img_reversed_data)
img_reversed
# Out:
# <PIL.Image.Image image mode=RGB size=640x377 at 0x1AB2C590CD0>

# %% [markdown]
# Rotate the Photo

# %%
#TODO do this myself
img_rotated_data = np.rot90(img_data)
img_rotated = Image.fromarray(img_rotated_data)
img_rotated
# Out:
# <PIL.Image.Image image mode=RGB size=377x640 at 0x1AB2C590BE0>
